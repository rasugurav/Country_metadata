# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Metadata_Country.csv')

# %%
df.head()
# Out:
#   Country Code                     Region          IncomeGroup SpecialNotes  \
# 0          ABW  Latin America & Caribbean          High income          NaN
# 1          AFG                 South Asia           Low income          NaN
# 2          AGO         Sub-Saharan Africa  Lower middle income          NaN
# 3          ALB      Europe & Central Asia  Upper middle income          NaN
# 4          AND      Europe & Central Asia          High income          NaN
#
#      TableName  Unnamed: 5
# 0        Aruba         NaN
# 1  Afghanistan         NaN
# 2       Angola         NaN
# 3      Albania         NaN
# 4      Andorra         NaN

# %%
df1=pd.read_csv('Metadata_Indicator.csv')
df1
# Out:
#    INDICATOR_CODE                           INDICATOR_NAME  \
# 0  EG.ELC.ACCS.ZS  Access to electricity (% of population)
#
#                                          SOURCE_NOTE  \
# 0  Access to electricity is the percentage of pop...
#
#                                  SOURCE_ORGANIZATION  Unnamed: 4
# 0  World Bank, Sustainable Energy for All (SE4ALL...         NaN

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   INDICATOR_CODE       1 non-null      object
#  1   INDICATOR_NAME       1 non-null      object
#  2   SOURCE_NOTE          1 non-null      object
#  3   SOURCE_ORGANIZATION  1 non-null      object
#  4   Unnamed: 4           0 non-null      float64
# dtypes: float64(1), object(4)
# memory usage: 168.0+ bytes

# %%
df2=pd.read_csv('electricityaccess.csv',skiprows=3)

# %%
df2.head()
# Out:
#   Country Name Country Code                           Indicator Name  \
# 0        Aruba          ABW  Access to electricity (% of population)
# 1  Afghanistan          AFG  Access to electricity (% of population)
# 2       Angola          AGO  Access to electricity (% of population)
# 3      Albania          ALB  Access to electricity (% of population)
# 4      Andorra          AND  Access to electricity (% of population)
#
#    Indicator Code  1960  1961  1962  1963  1964  1965  ...      2012  \
# 0  EG.ELC.ACCS.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...  100.0000
# 1  EG.ELC.ACCS.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...   69.1000
# 2  EG.ELC.ACCS.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...   35.6665
# 3  EG.ELC.ACCS.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...   99.9000
# 4  EG.ELC.ACCS.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...  100.0000
#
#          2013   2014   2015        2016        2017        2018  2019  2020  \
# ...

# %%
df2.isnull().sum().sort_values(ascending=False)
# Out:
# Unnamed: 65       264
# 1974              264
# 1987              264
# 1986              264
# 1985              264
#                  ...
# 2018                3
# Indicator Code      0
# Indicator Name      0
# Country Code        0
# Country Name        0
# Length: 66, dtype: int64

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Unnamed: 5      263
# SpecialNotes    169
# IncomeGroup      46
# Region           46
# TableName         0
# Country Code      0
# dtype: int64

# %%
df1.isnull().sum().sort_values(ascending=False)
# Out:
# Unnamed: 4             1
# SOURCE_ORGANIZATION    0
# SOURCE_NOTE            0
# INDICATOR_NAME         0
# INDICATOR_CODE         0
# dtype: int64

# %%
df2.drop(['Unnamed: 65','1960','1961','1962','1963','1964','1965','1966','1967','1968','1969','1970','1971','1972','1973','1974','1975','1976','1977','1978','1979','1980','1981','1982','1983','1984','1985','1986','1987','1988','1989','1990','1991','1992','1993','1994','1995','1996','2020','2019'
],axis=1,inplace=True)

# %%
df2
# Out:
#      Country Name Country Code                           Indicator Name  \
# 0           Aruba          ABW  Access to electricity (% of population)
# 1     Afghanistan          AFG  Access to electricity (% of population)
# 2          Angola          AGO  Access to electricity (% of population)
# 3         Albania          ALB  Access to electricity (% of population)
# 4         Andorra          AND  Access to electricity (% of population)
# ..            ...          ...                                      ...
# 259        Kosovo          XKX  Access to electricity (% of population)
# 260   Yemen, Rep.          YEM  Access to electricity (% of population)
# 261  South Africa          ZAF  Access to electricity (% of population)
# 262        Zambia          ZMB  Access to electricity (% of population)
# 263      Zimbabwe          ZWE  Access to electricity (% of population)
#
#      Indicator Code        1997        1998        1999        2000  \
# ...

# %%
df2['1997'].fillna(df2['1997'].median(),inplace=True)
df2['1998'].fillna(df2['1998'].median(),inplace=True)
df2['1999'].fillna(df2['1999'].median(),inplace=True)
df2['2000'].fillna(df2['2000'].median(),inplace=True)
df2['2001'].fillna(df2['2001'].median(),inplace=True)
df2['2002'].fillna(df2['2002'].median(),inplace=True)
df2['2003'].fillna(df2['2003'].median(),inplace=True)
df2['2004'].fillna(df2['2004'].median(),inplace=True)
df2['2005'].fillna(df2['2005'].median(),inplace=True)
df2['2006'].fillna(df2['2006'].median(),inplace=True)
df2['2007'].fillna(df2['2007'].median(),inplace=True)
df2['2008'].fillna(df2['2008'].median(),inplace=True)
df2['2009'].fillna(df2['2009'].median(),inplace=True)
df2['2010'].fillna(df2['2010'].median(),inplace=True)
df2['2011'].fillna(df2['2011'].median(),inplace=True)
df2['2012'].fillna(df2['2012'].median(),inplace=True)
df2['2013'].fillna(df2['2013'].median(),inplace=True)
df2['2014'].fillna(df2['2014'].median(),inplace=True)
df2['2015'].fillna(df2['2015'].median(),inplace=True)
df2['2016'].fillna(df2['2016'].median(),inplace=True)
df2['2017'].fillna(df2['2017'].median(),inplace=True)
df2['2018'].fillna(df2['2018'].median(),inplace=True)

# %%
df.drop(['Unnamed: 5','SpecialNotes'],axis=1,inplace=True)

# %%
df.head()
# Out:
#   Country Code                     Region          IncomeGroup    TableName
# 0          ABW  Latin America & Caribbean          High income        Aruba
# 1          AFG                 South Asia           Low income  Afghanistan
# 2          AGO         Sub-Saharan Africa  Lower middle income       Angola
# 3          ALB      Europe & Central Asia  Upper middle income      Albania
# 4          AND      Europe & Central Asia          High income      Andorra

# %%
df['IncomeGroup'].fillna(df.IncomeGroup.mode()[0],inplace=True)
df['Region'].fillna(df.Region.mode()[0],inplace=True)

# %%
df.head(10)
# Out:
#   Country Code                      Region          IncomeGroup  \
# 0          ABW   Latin America & Caribbean          High income
# 1          AFG                  South Asia           Low income
# 2          AGO          Sub-Saharan Africa  Lower middle income
# 3          ALB       Europe & Central Asia  Upper middle income
# 4          AND       Europe & Central Asia          High income
# 5          ARB       Europe & Central Asia          High income
# 6          ARE  Middle East & North Africa          High income
# 7          ARG   Latin America & Caribbean  Upper middle income
# 8          ARM       Europe & Central Asia  Upper middle income
# 9          ASM         East Asia & Pacific  Upper middle income
#
#               TableName
# 0                 Aruba
# 1           Afghanistan
# 2                Angola
# 3               Albania
# 4               Andorra
# 5            Arab World
# 6  United Arab Emirates
# 7             Argentina
# 8               Armenia
# ...

# %%
plt.figure(figsize=(15,8))
sns.set_theme(style="darkgrid")
ax = sns.countplot(y="IncomeGroup", hue="Region", data=df)

# %%
df2.describe()
# Out:
#              1997        1998        1999        2000        2001        2002  \
# count  264.000000  264.000000  264.000000  264.000000  264.000000  264.000000
# mean    84.526188   82.932120   82.180938   78.169938   77.565710   77.714620
# std     28.255682   28.142445   28.611025   30.190560   30.440958   30.295328
# min      1.054141    1.789617    2.249965    2.704968    1.413913    3.538844
# 25%     88.717060   82.517011   78.865910   69.387737   63.923254   60.641820
# 50%     98.261974   96.372546   96.316216   93.303423   93.653237   94.279808
# 75%    100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# max    100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
#
#              2003        2004        2005        2006  ...        2009  \
# count  264.000000  264.000000  264.000000  264.000000  ...  264.000000
# mean    78.195381   78.429554   78.325738   78.751341  ...   79.129018
# ...

# %%
df3=df2.T

# %%
df3
# Out:
#                                                     0    \
# Country Name                                      Aruba
# Country Code                                        ABW
# Indicator Name  Access to electricity (% of population)
# Indicator Code                           EG.ELC.ACCS.ZS
# 1997                                             98.262
# 1998                                            96.3725
# 1999                                            96.3162
# 2000                                            91.6604
# 2001                                                100
# 2002                                                100
# 2003                                                100
# 2004                                                100
# 2005                                                100
# 2006                                                100
# 2007                                                100
# 2008                                                100
# ...

# %%
plt.figure(figsize=(20,10))
ax = sns.catplot(x="Country Code", y="IncomeGroup", data=df)

# %%
sns.catplot(x="Country Name", y="2008",  data=df2)
